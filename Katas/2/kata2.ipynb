# %%
# !python3 -m venv env

# %%
# !source env/bin/activate

# %%
# !pip freeze
# Out:
# anyio==3.5.0
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asgiref==3.5.0
# asttokens==2.0.5
# attrs==19.3.0
# Automat==0.8.0
# autopep8==1.6.0
# backcall==0.2.0
# black==22.1.0
# bleach==4.1.0
# blinker==1.4
# certifi==2019.11.28
# cffi==1.15.0
# chardet==3.0.4
# click==8.0.4
# cloud-init==21.4
# colorama==0.4.3
# command-not-found==0.3
# configobj==5.0.6
# constantly==15.1.0
# cryptography==2.8
# cycler==0.11.0
# dbus-python==1.2.16
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# distro==1.4.0
# distro-info===0.23ubuntu1
# entrypoints==0.3
# executing==0.8.2
# Faker==12.3.0
# fastapi==0.73.0
# fonttools==4.29.1
# greenlet==1.1.2
# h11==0.13.0
# httplib2==0.14.0
# httptools==0.3.0
# hyperlink==19.0.0
# idna==2.8
# importlib-metadata==1.5.0
# incremental==16.10.1
# ipykernel==6.9.1
# ipython==8.0.1
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# jedi==0.18.1
# Jinja2==2.10.1
# jsonpatch==1.22
# jsonpointer==2.0
# jsonschema==3.2.0
# jupyter-client==7.1.2
# ...

# %%
# !pip install python-dateutil

# %%
# !pip freeze
# Out:
# anyio==3.5.0
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asgiref==3.5.0
# asttokens==2.0.5
# attrs==19.3.0
# Automat==0.8.0
# autopep8==1.6.0
# backcall==0.2.0
# black==22.1.0
# bleach==4.1.0
# blinker==1.4
# certifi==2019.11.28
# cffi==1.15.0
# chardet==3.0.4
# click==8.0.4
# cloud-init==21.4
# colorama==0.4.3
# command-not-found==0.3
# configobj==5.0.6
# constantly==15.1.0
# cryptography==2.8
# cycler==0.11.0
# dbus-python==1.2.16
# debugpy==1.5.1
# decorator==5.1.1
# defusedxml==0.7.1
# distro==1.4.0
# distro-info===0.23ubuntu1
# entrypoints==0.3
# executing==0.8.2
# Faker==12.3.0
# fastapi==0.73.0
# fonttools==4.29.1
# greenlet==1.1.2
# h11==0.13.0
# httplib2==0.14.0
# httptools==0.3.0
# hyperlink==19.0.0
# idna==2.8
# importlib-metadata==1.5.0
# incremental==16.10.1
# ipykernel==6.9.1
# ipython==8.0.1
# ipython-genutils==0.2.0
# ipywidgets==7.6.5
# jedi==0.18.1
# Jinja2==2.10.1
# jsonpatch==1.22
# jsonpointer==2.0
# jsonschema==3.2.0
# jupyter-client==7.1.2
# ...

# %%
# !deactivate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/tony/CursoIntroPython/Katas/2/kata2.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/tony/CursoIntroPython/Katas/2/kata2.ipynb#ch0000005vscode-remote?line=0'>1</a> deactivate
#
# NameError: name 'deactivate' is not defined
